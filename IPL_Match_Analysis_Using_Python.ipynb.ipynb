# %%
 ## Load the Datasets :

# %%
# Importing necessary libraries
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical computations
import matplotlib.pyplot as plt  # For creating visualizations
# +%matplotlib inline+

matches=pd.read_csv("matches.csv")
deliveries=pd.read_csv("deliveries.csv")

# %%
matches.head() # Return first 5 rows of matches DataFrame
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head() # Return first 5 rows of deliveries DataFrame
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
matches.info() ##Provides a summary of the DataFrame, including the number of non-null entries and data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
deliveries.info() ##Provides a summary of the DataFrame, including the number of non-null entries and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
matches.describe() # Generate Descriptive Statisticks for numerical column(mean,median,std)
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
deliveries.describe() # Generate Descriptive Statistics for Numeric Column(mean,median std)
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#  Data Loading:-

# Match dataset insight:-
# - Matches dataset has 756 rows and 18 columns, with nulls in 'city', 'winner', 'player_of_match', and 'umpire1','umpire2','umpire3'.
# - Matches dataset has 5 numerical column and 13 categorical columns.
# - Important Columns in Match dataset: "winner" ,"city", "venue", "win_by_runs", "win_by_wickets", "player_of_match".

# Deliveries dataset insight
# - Deliveries dataset has 179,078 rows and 21 columns, with nulls in  "player_dismissed","dismissal_kind","fielder".
# - Deliveries dataset has 13 numerical column and 8 categorical columns.
# - Important Columns in deliveries dataser: "batsman", "batsman_run", "player_dismissed", "dismissal_kind", "match_id", "total_runs", "wide_runs","noball_runs","legbye_runs".

# %% [markdown]
# ## Data Cleaning :

# %%
#check null values in matches data sets
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
# Check null values in deliveries dataset
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
#check missing value percentage in matches dataset
matches.isnull().sum()/len(matches)*100
# Out:
# id                  0.000000
# season              0.000000
# city                0.925926
# date                0.000000
# team1               0.000000
# team2               0.000000
# toss_winner         0.000000
# toss_decision       0.000000
# result              0.000000
# dl_applied          0.000000
# winner              0.529101
# win_by_runs         0.000000
# win_by_wickets      0.000000
# player_of_match     0.529101
# venue               0.000000
# umpire1             0.264550
# umpire2             0.264550
# umpire3            84.259259
# dtype: float64

# %%
#check missing value percentage in deliveries dataset
deliveries.isnull().sum()/len(deliveries)*100
# Out:
# match_id             0.000000
# inning               0.000000
# batting_team         0.000000
# bowling_team         0.000000
# over                 0.000000
# ball                 0.000000
# batsman              0.000000
# non_striker          0.000000
# bowler               0.000000
# is_super_over        0.000000
# wide_runs            0.000000
# bye_runs             0.000000
# legbye_runs          0.000000
# noball_runs          0.000000
# penalty_runs         0.000000
# batsman_runs         0.000000
# extra_runs           0.000000
# total_runs           0.000000
# player_dismissed    95.066954
# dismissal_kind      95.066954
# fielder             96.399334
# dtype: float64

# %%
# Drop irrelevant Columns in matches dataset
matches.drop(columns=["umpire1","umpire2","umpire3"], inplace=True)

# %%
# Handling null values in the Matches dataset
matches['city'].fillna('Unknown', inplace=True)
matches['winner'].fillna('No Result', inplace=True)
matches['player_of_match'].fillna('No Award', inplace=True)

# Verify if all null values are handled
print(matches.isnull().sum())
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# dtype: int64
# C:\Users\hp\AppData\Local\Temp\ipykernel_2984\3933654915.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   matches['city'].fillna('Unknown', inplace=True)
# ...

# %%
#Drop irrelevant Columns in deliveries dataset
deliveries.drop(columns=["fielder"],inplace=True)

# %%
# Handling Null Values in deliveries dataset
deliveries['player_dismissed'] = deliveries['player_dismissed'].fillna('Unknown')
deliveries['dismissal_kind'] = deliveries['dismissal_kind'].fillna('Not Applicable')
# Verify its all null value are Verified 
print(deliveries.isnull().sum())
# Out:
# match_id            0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# is_super_over       0
# wide_runs           0
# bye_runs            0
# legbye_runs         0
# noball_runs         0
# penalty_runs        0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# player_dismissed    0
# dismissal_kind      0
# dtype: int64

# %%
# Check Duplicated Values in Matches dataset
matches.duplicated().sum() #Counts the total number of duplicate rows in the DataFrame.
# Out:
# 0

# %%
# Check Duplicated Values in deliveries dataset
deliveries.duplicated().sum() # Counts the total number of duplicate rows in the DataFrame.
# Out:
# 23

# %%
# Count Duplicate Value in Each Row
deliveries.apply(lambda x:x.duplicated().sum())
# Out:
# match_id            178322
# inning              179073
# batting_team        179063
# bowling_team        179063
# over                179058
# ball                179069
# batsman             178562
# non_striker         178567
# bowler              178673
# is_super_over       179076
# wide_runs           179072
# bye_runs            179073
# legbye_runs         179072
# noball_runs         179073
# penalty_runs        179076
# batsman_runs        179070
# extra_runs          179071
# total_runs          179068
# player_dismissed    178590
# dismissal_kind      179068
# dtype: int64

# %%
# Drop duplicates Values in deliveries dataset
deliveries.drop_duplicates(inplace=True)

# Check its all duplicated values are  Drop
print(deliveries.isnull().sum())
# Out:
# match_id            0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# is_super_over       0
# wide_runs           0
# bye_runs            0
# legbye_runs         0
# noball_runs         0
# penalty_runs        0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# player_dismissed    0
# dismissal_kind      0
# dtype: int64

# %%
# Correct Some Columns Name in Mates dataset
matches.rename(columns={"team1": "team_1", "team2": "team_2", "player_of_match":"player_of_the_match"}, inplace=True)
matches.head()
# Out:
#    id  season       city        date                       team_1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                         team_2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# Data Cleaning Insight:-

# Matches dataset :-
# - drop umpire3 column in matches dataset
# - Filled nulls: City ("Unknown"), Winner ("No Result"), Umpires1 ("Unknown Umpire"), Umpire2 ("Unknown Umpire"), Player of Match ("No Award").
# - During the data cleaning process, I renamed 'team1' and 'team2' to 'team_1' and 'team_2', and changed 'player_of_match' to 'player_of_the_match' to make the column names clearer and more consistent.

# Deliveries dataset :-
# - drop fielder column in deliveries dataset
# - filled nulls: player_dismissed ("Unknown"), dismissal_kind ("Not Applicable")
# - drop duplicates value in deliveries datasets

# %% [markdown]
# # Exploratory Data Analysis (EDA) :

# %% [markdown]
# Match-Level Analysis:

# %% [markdown]
# Q-1: Which team won the most matches:

# %%
most_winning_team = matches['winner'].value_counts().idxmax()  # Team name
most_wins_count = matches['winner'].value_counts().max()       # Number of wins


print(f"The team with the most wins is {most_winning_team} with {most_wins_count} wins.")
# Out:
# The team with the most wins is Mumbai Indians with 109 wins.

# %% [markdown]
# Q-3: Average winning margin (runs aur wickets)?

# %%
average_win_runs=matches["win_by_runs"].mean()
print("Average win by runs:",average_win_runs)

average_win_wicket=matches["win_by_wickets"].mean()
print("Average win by wickets:",average_win_wicket)
print()
# Out:
# Average win by runs: 13.283068783068783
# Average win by wickets: 3.3505291005291005

# %% [markdown]
# Q-3: Top 5 cities  where matches were held:

# %%
print("Top 5 cities where matches were held:")
top_cities = matches['city'].value_counts().head(5)
for city, count in top_cities.items():
   print(f"   - {city}: {count} matches")
# Out:
# Top 5 cities where matches were held:
#    - Mumbai: 101 matches
#    - Kolkata: 77 matches
#    - Delhi: 74 matches
#    - Bangalore: 66 matches
#    - Hyderabad: 64 matches

# %% [markdown]
# Q-4: Venue with most match hosted:

# %%
top_venue = matches['venue'].value_counts().idxmax()
top_venue_count=matches["venue"].value_counts().max()
print(f"Top venue with most Matches Hosted {top_venue} with {top_venue_count} matches")
print()
# Out:
# Top venue with most Matches Hosted Eden Gardens with 77 matches

# %% [markdown]
# Q-5: Player with the most "Player of the match" Award:

# %%
top_player = matches['player_of_the_match'].value_counts().idxmax()
player_awards = matches['player_of_the_match'].value_counts().max()
print(f"The player with the most 'Player of the Match' awards is {top_player} with {player_awards} awards.")
print()
# Out:
# The player with the most 'Player of the Match' awards is CH Gayle with 21 awards.

# %% [markdown]
# Ball-Level Analysis:

# %% [markdown]
# Q-6: Batsman scored most runs overall:

# %%
batsman_name = deliveries.groupby('batsman')['batsman_runs'].sum().idxmax()
batsman_runs = deliveries.groupby('batsman')['batsman_runs'].sum().max()
print(f"The batsman with the most runs is {batsman_name} with {batsman_runs} runs.")
print()
# Out:
# The batsman with the most runs is V Kohli with 5434 runs.

# %% [markdown]
# Q-7: Bowler with the most wickets:

# %%
# Filter rows where a player was dismissed and dismissal_kind is valid
wickets_data = deliveries[(~deliveries['player_dismissed'].isna()) & (~deliveries['dismissal_kind'].isna())]

#  Count dismissals for each bowler
wickets_count = wickets_data['bowler'].value_counts()

# Find the bowler with the most wickets
most_wickets = wickets_count.idxmax()
wickets_taken = wickets_count.max()

print(f"The bowler with the most wickets is :- \n{most_wickets} with {wickets_taken} wickets.")
print()
# Out:
# The bowler with the most wickets is :-
# Harbhajan Singh with 3451 wickets.

# %% [markdown]
# Q-8: Distribution of extras:

# %%
extra_column=["wide_runs","noball_runs","bye_runs","legbye_runs"] 
total_distributions=deliveries[extra_column].sum()
print("Distribution of extras:-","\n",total_distributions)
print()
# Out:
# Distribution of extras:-
#  wide_runs      6576
# noball_runs     749
# bye_runs        884
# legbye_runs    3784
# dtype: int64

# %% [markdown]
# Q-9: Team scored highest runs in a single match:

# %%
# Group data by match_id and batting_team, then calculate total runs
team_scores = deliveries.groupby(['match_id', 'batting_team'])['total_runs'].sum().reset_index()

# Find the row with the highest total runs
highest_score = team_scores.loc[team_scores['total_runs'].idxmax()]

# Print the result
print("Match ID:", highest_score['match_id'])
print("Team:", highest_score['batting_team'])
print("Highest Runs Scored:", highest_score['total_runs'])
# Out:
# Match ID: 411
# Team: Royal Challengers Bangalore
# Highest Runs Scored: 263

# %% [markdown]
# Q-10: Trend of total runs scored per over in a match:

# %%
run_per_over=deliveries.groupby("over")["total_runs"].sum().reset_index()
run_per_over.plot(x="over",y="total_runs",kind="line",marker="*",color="green")
plt.xlabel("Over")
plt.ylabel("Total_Runs")
plt.title("Total Runs in Per Over")
plt.grid(True)
plt.savefig("Total Runs in Per Over.png")
plt.show()

# %% [markdown]
# Data Vizulazation:

# %%
# Top 5 teams with the most wins

top_teams = matches['winner'].value_counts().head(5)

# Horizontal Bar Chart
plt.figure(figsize=(10,6))

plt.barh(
    top_teams.index,
    top_teams.values,
    color='skyblue'
)

plt.title('Top 5 Teams with Most Wins')

plt.xlabel('Number of Wins')
plt.ylabel('Teams')

plt.tight_layout()

plt.savefig(
    'Top 5 Teams with Most Wins.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
# Top 5 batsmen with the highest runs

batsman_runs = deliveries.groupby('batsman')['batsman_runs'] \
                         .sum() \
                         .sort_values(ascending=False) \
                         .head(5)

# Horizontal Bar Chart
plt.figure(figsize=(10,6))

plt.barh(
    batsman_runs.index,
    batsman_runs.values,
    color='orange'
)

plt.title('Top 5 Batsmen with the Highest Runs')

plt.xlabel('Total Runs')
plt.ylabel('Batsmen')

plt.tight_layout()

plt.savefig(
    'Top_5_Batsmen_with_Highest_Runs.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %%
# Winning Margin Distribution - Runs and Wickets
plt.figure(figsize=(12, 6))

# Winning by runs
plt.subplot(1, 2, 1)
plt.hist(matches['win_by_runs'],color='blue')
plt.title('Winning Margin (Runs) Distribution')
plt.xlabel('Runs')
plt.ylabel('Frequency')

# Winning by wickets
plt.subplot(1, 2, 2)
plt.hist(matches['win_by_wickets'],color='green')
plt.title('Winning Margin (Wickets) Distribution')
plt.xlabel('Wickets')
plt.ylabel('Frequency')
plt.tight_layout()
plt.savefig('Winning Margin (Wickets) Distribution.png')  # Save chart as PN
plt.show()

# %%
#Line plot showing runs scored across overs in a specific match
# Select a specific match_id (e.g., 1)
match_id = 1
match_over_runs = deliveries[deliveries['match_id'] == match_id].groupby('over')['total_runs'].sum()

# Line Plot
plt.figure(figsize=(10, 5))
plt.plot(match_over_runs.index, match_over_runs.values, marker='o', linestyle='-', color='purple')
plt.title(f'Total Runs Scored per Over - Match {match_id}')
plt.xlabel('Over')
plt.ylabel('Total Runs')
plt.grid(True)
plt.savefig("Total Runs Scored per Over- Match.png")
plt.show()

# %%
matches.to_csv('cleaned_matches.csv', index=False)
deliveries.to_csv('cleaned_deliveries.csv', index=False)

# %% [markdown]
# Conclusions:-

# %%
# Match-Level Analysis:
# 1. Team with the most wins: Mumbai Indians (109 wins).
# 2. Average winning margin:
#    - Runs: 13.28.
#    - Wickets: 3.35.
# 3. Top 5 cities with most matches hosted:
#    - Mumbai: 101 matches.
#    - Kolkata: 77 matches.
#    - Delhi: 74 matches.
#    - Bangalore: 66 matches.
#    - Hyderabad: 64 matches.
# 4. Venue with the most matches hosted: Eden Gardens (77 matches).
# 5. Player with the most "Player of the Match" awards: Chris Gayle (21 awards).

# Ball-Level Analysis:
# 6. Batsman with the most runs: Virat Kohli (6624 runs).
# 7. Bowler with the most wickets: Harbhajan Singh(3451 wickets).
# 8. Extras Distribution:
#    - Wide runs: 6576.
#    - No-ball runs: 749.
#    - Bye runs: 884.
#    - Leg-bye runs: 3784.
# 9. Team with the highest runs in a single match: 
#    Royal Challengers Bangalore (263 runs in Match ID: 411).

# Insights and Recommendations:
# - Mumbai Indians have been the most successful IPL team.
# - Eden Gardens is a prominent venue for hosting IPL matches.
# - Power-hitters like Chris Gayle are crucial in T20 cricket.
# - Reducing extras can significantly impact match results.
# - Strong batting lineups are vital for scoring high runs and winning.
